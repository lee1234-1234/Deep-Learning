# %% [markdown]
# # ML mini project #2

# %%
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
import random
import os

PROJECT_ROOT_DIR = "."
CHAPTER_ID = "classification"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
df = pd.read_csv('C:/Users/tglee/Nananana/Deep_Learning/Final_Deep/DL_mini_project/2/train.csv')
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %% [markdown]
# - subject와 Acitivity에서 비슷한 데이터가 연속되어서 나옴! => shuffle 해주기!

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df.head()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1334           0.270514          -0.019739          -0.129706
# 196            0.278720          -0.014508          -0.115309
# 3679           0.273361          -0.012563          -0.109833
# 5658           0.273477          -0.041435          -0.112665
# 3817           0.276492          -0.007673          -0.095866
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1334         -0.988424         -0.980260         -0.968742         -0.989403
# 196          -0.998038         -0.985794         -0.998455         -0.998672
# 3679         -0.982366         -0.971776         -0.967996         -0.982274
# 5658         -0.148514          0.060106         -0.387167         -0.260448
# 3817         -0.976019         -0.808805         -0.870906         -0.978138
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# ...

# %% [markdown]
# ## 범주형 특성 처리

# %%
from sklearn.preprocessing import LabelEncoder

df_cat = df['Activity']
encoder = LabelEncoder()
encoder.fit(df_cat)
df_encoded = encoder.transform(df_cat)

# %%
df['Activity'] = df_encoded
df['Activity']
# Out:
# 1334    2
# 196     2
# 3679    1
# 5658    5
# 3817    2
#        ..
# 3079    2
# 1802    1
# 3235    5
# 576     1
# 7123    5
# Name: Activity, Length: 7352, dtype: int64

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1334           0.270514          -0.019739          -0.129706
# 196            0.278720          -0.014508          -0.115309
# 3679           0.273361          -0.012563          -0.109833
# 5658           0.273477          -0.041435          -0.112665
# 3817           0.276492          -0.007673          -0.095866
# ...                 ...                ...                ...
# 3079           0.273404          -0.017144          -0.117692
# 1802           0.282293          -0.022770          -0.096295
# 3235           0.207951           0.001826          -0.092661
# 576            0.250264           0.026936          -0.243369
# 7123           0.208901           0.016275          -0.246668
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1334         -0.988424         -0.980260         -0.968742         -0.989403
# ...

# %% [markdown]
# -> Activity에 해당하는 데이터들이 숫자로 바뀐 것을 확인할 수 있다

# %%
X = df.drop(['subject', 'Activity'], axis=1).copy() # subject와 Activity 열 삭제
X
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1334           0.270514          -0.019739          -0.129706
# 196            0.278720          -0.014508          -0.115309
# 3679           0.273361          -0.012563          -0.109833
# 5658           0.273477          -0.041435          -0.112665
# 3817           0.276492          -0.007673          -0.095866
# ...                 ...                ...                ...
# 3079           0.273404          -0.017144          -0.117692
# 1802           0.282293          -0.022770          -0.096295
# 3235           0.207951           0.001826          -0.092661
# 576            0.250264           0.026936          -0.243369
# 7123           0.208901           0.016275          -0.246668
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1334         -0.988424         -0.980260         -0.968742         -0.989403
# ...

# %%
X.shape
# Out:
# (7352, 561)

# %%
y = df['Activity'].copy() # 데이터셋에서 Activity 분리
y
# Out:
# 1334    2
# 196     2
# 3679    1
# 5658    5
# 3817    2
#        ..
# 3079    2
# 1802    1
# 3235    5
# 576     1
# 7123    5
# Name: Activity, Length: 7352, dtype: int64

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.optimizers import SGD

# def build_model():
#     model = keras.models.Sequential([
#         keras.layers.Flatten(input_shape=(X.shape[1],)),
#         keras.layers.Dense(300, activation="relu"),
#         keras.layers.Dense(100, activation="relu"),
#         keras.layers.Dense(10, activation="softmax")
#     ])

#     # model.compile(loss="sparse_categorical_crossentropy",
#     #               optimizer="sgd",
#     #               metrics=["accuracy"])

#     # model.compile(loss="sparse_categorical_crossentropy",
#     #               optimizer=Adam(learning_rate=0.0007),
#     #               metrics=["accuracy"])


#     # model.compile(
#     # loss="sparse_categorical_crossentropy",
#     # optimizer=SGD(learning_rate=0.01, momentum=0.9, nesterov=True),
#     # metrics=["accuracy"])

    
#     model.compile(
#     loss="sparse_categorical_crossentropy",
#     optimizer=SGD(learning_rate=0.005, momentum=0.9, nesterov=True),
#     metrics=["accuracy"])

#     # model.compile(
#     # loss="sparse_categorical_crossentropy",
#     # optimizer=SGD(learning_rate=0.004, momentum=0.9, nesterov=True),
#     # metrics=["accuracy"])
    
#     return model

# %%
from tensorflow.keras.optimizers import SGD

def build_model():
    model = keras.models.Sequential([
        keras.layers.Flatten(input_shape=(X.shape[1],)),

        keras.layers.Dense(512, activation="relu"),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(64, activation="relu"),

        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=SGD(learning_rate=0.005, momentum=0.9, nesterov=True),
        metrics=["accuracy"]
    )

    return model

# %%
#안쓰는거 랩컴으로 실험중
# def build_model():
#     model = keras.models.Sequential([
#         keras.layers.Flatten(input_shape=(X.shape[1],)),

#         keras.layers.Dense(256, activation='relu'),
#         keras.layers.BatchNormalization(),
#         keras.layers.Dropout(0.3),

#         keras.layers.Dense(128, activation='relu'),
#         keras.layers.BatchNormalization(),
#         keras.layers.Dropout(0.3),

#         keras.layers.Dense(10, activation='softmax')
#     ])

#     # SGD 적용
#     optimizer = keras.optimizers.SGD(
#         learning_rate=0.001,   # 기본값보다 살짝 낮은 안정적 설정
#         momentum=0.9,          # 빠른 수렴 + 진동 방지
#         nesterov=True          # 추가 성능 향상 가능성
#     )

#     model.compile(
#         loss="sparse_categorical_crossentropy",
#         optimizer=optimizer,
#         metrics=["accuracy"]
#     )

#     return model

# %%
model = build_model()
# Out:
# C:\Users\tglee\anaconda3\envs\tf-env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 561)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │         287,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │          32,896 │
# ...

# %%
# 여기서 epoch 수 조정
history = model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6583 - loss: 0.8580
# Epoch 2/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9363 - loss: 0.1716
# Epoch 3/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9530 - loss: 0.1211
# Epoch 4/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9611 - loss: 0.0980
# Epoch 5/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9694 - loss: 0.0800
# Epoch 6/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9726 - loss: 0.0789
# Epoch 7/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9740 - loss: 0.0672
# Epoch 8/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9773 - loss: 0.0633
# Epoch 9/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9770 - loss: 0.0562
# Epoch 10/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9737 - loss: 0.0608
# Epoch 11/20
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9790 - loss: 0.0506
# ...

# %%
# import numpy as np

# k = 5
# num_val_samples = len(X) // k
# num_epochs = 300
# all_scores = []
# for i in range(k):
#     print('processing fold #', i)

#     X_val = X[i * num_val_samples: (i + 1) * num_val_samples]
#     y_val = y[i * num_val_samples: (i + 1) * num_val_samples]

#     partial_train_data = np.concatenate(
#         [X[:i * num_val_samples],
#          X[(i + 1) * num_val_samples:]],
#         axis=0)
#     partial_train_targets = np.concatenate(
#         [y[:i * num_val_samples],
#          y[(i + 1) * num_val_samples:]],
#         axis=0)

#     model = build_model()
#     model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, verbose=0)

#     loss, acc = model.evaluate(X_val, y_val, verbose=0)
#     all_scores.append(acc)

#기존코드의 k-fold부분임

# %%
k = 5
num_val = len(X) // k
num_epochs = 300
all_scores = []

for i in range(k):
    print('processing fold #', i)

    X_val = X[i * num_val: (i + 1) * num_val]
    y_val = y[i * num_val: (i + 1) * num_val]

    X_train_part = np.concatenate([X[:i * num_val], X[(i + 1) * num_val:]], axis=0)
    y_train_part = np.concatenate([y[:i * num_val], y[(i + 1) * num_val:]], axis=0)

    model = build_model()
    
    model.fit(X_train_part, y_train_part, epochs=num_epochs, verbose=1)

    val_loss, val_acc = model.evaluate(X_val, np.array(y_val), verbose=0)
    all_scores.append(val_acc)
# Out:
# processing fold # 0
# C:\Users\tglee\anaconda3\envs\tf-env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6089 - loss: 1.0331
# Epoch 2/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9120 - loss: 0.2194
# Epoch 3/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9357 - loss: 0.1658
# Epoch 4/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9408 - loss: 0.1689
# Epoch 5/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9645 - loss: 0.0952
# Epoch 6/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9674 - loss: 0.0861
# Epoch 7/300
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9684 - loss: 0.0781
# Epoch 8/300
# ...

# %%
all_scores

# %%
np.mean(all_scores)
